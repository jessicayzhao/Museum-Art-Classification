# %%
# %% Cell 1: Import necessary libraries and set device
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# PyTorch and Torchvision imports
import torch
import torch.nn as nn
import torch.nn.functional as F  # Import functional API for pooling
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

# For TensorBoard logging
from torch.utils.tensorboard import SummaryWriter

# For computing the confusion matrix
from sklearn.metrics import confusion_matrix

# Set device (use GPU if available)
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
class ArtCNN(nn.Module):
    def __init__(self):
        super(ArtCNN, self).__init__()
        # First convolutional block: 3 -> 32
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.AvgPool2d(2, 2)  # Downsample: 224 -> 112
        )
        # Second convolutional block: 32 -> 64
        self.conv2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.AvgPool2d(2, 2)  # Downsample: 112 -> 56
        )
        
        # Adaptive pooling to get a fixed size (7x7)
        self.global_pool = nn.AdaptiveAvgPool2d((7, 7))  # Reduces 56x56 to 7x7

        # Flattened feature map size: 64 * 7 * 7 = 3,136 neurons
        self.fc1 = nn.Linear(64 * 7 * 7, 64)  # Smaller fully connected layer
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(64, 4)  # Output layer for 4 classes

    def forward(self, x):
        x = self.conv1(x)  # 224 -> 112
        x = self.conv2(x)  # 112 -> 56
        x = self.global_pool(x)  # 56 -> 7
        x = x.view(x.size(0), -1)  # Flatten
        embedding = torch.relu(self.fc1(x))
        embedding = self.dropout(embedding)
        logits = self.fc2(embedding)
        return logits, embedding

# %%
def compute_mean_std(dataset):
    loader = torch.utils.data.DataLoader(dataset, batch_size=64, shuffle=False, num_workers=8)
    mean = 0.
    std = 0.
    total_images = 0
    for images, _ in loader:
        batch_samples = images.size(0)
        # reshape to (batch, channels, H*W)
        images = images.view(batch_samples, images.size(1), -1)
        mean += images.mean(2).sum(0)
        std += images.std(2).sum(0)
        total_images += batch_samples
    mean /= total_images
    std /= total_images
    return mean, std

transform_simple = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])
dataset = torchvision.datasets.ImageFolder(root=r'art500k_period_3', transform=transform_simple)
mean, std = compute_mean_std(dataset)

# %%
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
])
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
])

full_dataset = torchvision.datasets.ImageFolder(
    root=r'art500k_period_3', 
    transform=transform_simple
)
indices = list(range(len(full_dataset)))
np.random.shuffle(indices)
train_size = int(0.8 * len(full_dataset))
train_indices = indices[:train_size]
test_indices = indices[train_size:]

# Now create two separate datasets with the appropriate transforms.
train_dataset = torchvision.datasets.ImageFolder(
    root=r'art500k_period_3', 
    transform=train_transform
)
test_dataset = torchvision.datasets.ImageFolder(
    root=r'art500k_period_3', 
    transform=test_transform
)

# Create Subset objects using the precomputed indices.
trainset_simple = torch.utils.data.Subset(train_dataset, train_indices)
testset_simple = torch.utils.data.Subset(test_dataset, test_indices)

# %%
# Create DataLoaders for training and test sets.
trainloader_simple = torch.utils.data.DataLoader(
    trainset_simple, batch_size=32, num_workers=16
)
testloader_simple = torch.utils.data.DataLoader(
    testset_simple, batch_size=32, shuffle=False, num_workers=16
)

print("Simple model data loaded: train size =", len(trainset_simple),
      ", test size =", len(testset_simple))
# Out:
# Simple model data loaded: train size = 23321 , test size = 5831

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import DataLoader
# Initialize the custom CNN and move it to the device
simple_model = ArtCNN().to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(simple_model.parameters(), lr=0.0001)

scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)
# Save loss values to graph later
train_loss_list = []
train_acc_list = []
test_loss_list = []
test_acc_list = []

# Train the custom CNN for a few epochs (e.g., 25 epochs)
num_epochs = 100
print("Training ArtCNN...")
for epoch in range(num_epochs):
    epoch_time = time.time()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    simple_model.train()  # set model to training mode
    for inputs, labels in trainloader_simple:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()           # zero the parameter gradients
        outputs, _ = simple_model(inputs)  # forward pass (we ignore the embedding here)
        loss = criterion(outputs, labels)
        loss.backward()                 # backpropagation
        optimizer.step()                # update weights

        running_loss += loss.item() * inputs.size(0)
        # Calculate training accuracy
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()
    epoch_loss = running_loss / len(trainset_simple)
    train_accuracy = 100 * correct_train / total_train

    # Evaluate on test data
    simple_model.eval()
    test_loss = 0.0
    correct_test = 0
    total_test = 0
    with torch.no_grad():
        for inputs, labels in testloader_simple:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs, _ = simple_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()
    epoch_test_loss = test_loss / len(testset_simple)
    test_accuracy = 100 * correct_test / total_test
    epoch_duration = time.time() - epoch_time

    scheduler.step(epoch_test_loss)

    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {epoch_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Test Loss: {epoch_test_loss:.4f}, Test Acc: {test_accuracy:.2f}%, Time: {epoch_duration:.2f}")
    train_loss_list.append(epoch_loss)
    train_acc_list.append(train_accuracy)
    test_loss_list.append(epoch_test_loss)
    test_acc_list.append(test_accuracy)
    
print("Finished training the CNN.")
# Out:
# Training ArtCNN...
# /share/u/jessica/.conda/envs/ml/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/100], Train Loss: 1.3182, Train Acc: 37.63%, Test Loss: 1.2704, Test Acc: 41.74%, Time: 36.92
# Epoch [2/100], Train Loss: 1.2792, Train Acc: 41.50%, Test Loss: 1.2429, Test Acc: 44.11%, Time: 35.78
# Epoch [3/100], Train Loss: 1.2631, Train Acc: 42.10%, Test Loss: 1.2233, Test Acc: 45.02%, Time: 35.95
# Epoch [4/100], Train Loss: 1.2525, Train Acc: 43.18%, Test Loss: 1.2216, Test Acc: 45.05%, Time: 36.11
# Epoch [5/100], Train Loss: 1.2436, Train Acc: 43.54%, Test Loss: 1.2129, Test Acc: 45.70%, Time: 36.58
# Epoch [6/100], Train Loss: 1.2331, Train Acc: 44.50%, Test Loss: 1.2018, Test Acc: 46.18%, Time: 38.09
# Epoch [7/100], Train Loss: 1.2317, Train Acc: 44.52%, Test Loss: 1.1986, Test Acc: 46.72%, Time: 38.49
# Epoch [8/100], Train Loss: 1.2225, Train Acc: 45.03%, Test Loss: 1.1942, Test Acc: 46.75%, Time: 37.33
# Epoch [9/100], Train Loss: 1.2166, Train Acc: 45.49%, Test Loss: 1.1848, Test Acc: 47.28%, Time: 36.14
# Epoch [10/100], Train Loss: 1.2164, Train Acc: 45.40%, Test Loss: 1.1764, Test Acc: 47.92%, Time: 36.31
# Epoch [11/100], Train Loss: 1.2063, Train Acc: 46.05%, Test Loss: 1.1743, Test Acc: 48.24%, Time: 36.41
# Epoch [12/100], Train Loss: 1.2067, Train Acc: 46.13%, Test Loss: 1.1745, Test Acc: 47.76%, Time: 37.51
# Epoch [13/100], Train Loss: 1.2029, Train Acc: 46.36%, Test Loss: 1.1687, Test Acc: 48.79%, Time: 37.07
# Epoch [14/100], Train Loss: 1.2001, Train Acc: 46.84%, Test Loss: 1.1666, Test Acc: 48.96%, Time: 36.05
# Epoch [15/100], Train Loss: 1.1956, Train Acc: 46.43%, Test Loss: 1.1627, Test Acc: 49.22%, Time: 36.46
# Epoch [16/100], Train Loss: 1.1919, Train Acc: 47.03%, Test Loss: 1.1619, Test Acc: 48.88%, Time: 36.17
# Epoch [17/100], Train Loss: 1.1879, Train Acc: 47.29%, Test Loss: 1.1565, Test Acc: 48.98%, Time: 35.91
# Epoch [18/100], Train Loss: 1.1912, Train Acc: 46.91%, Test Loss: 1.1595, Test Acc: 48.76%, Time: 36.07
# Epoch [19/100], Train Loss: 1.1824, Train Acc: 47.53%, Test Loss: 1.1540, Test Acc: 48.98%, Time: 36.19
# Epoch [20/100], Train Loss: 1.1828, Train Acc: 47.31%, Test Loss: 1.1499, Test Acc: 49.51%, Time: 36.12
# Epoch [21/100], Train Loss: 1.1781, Train Acc: 47.70%, Test Loss: 1.1477, Test Acc: 49.51%, Time: 36.09
# Epoch [22/100], Train Loss: 1.1744, Train Acc: 47.79%, Test Loss: 1.1526, Test Acc: 49.29%, Time: 36.31
# Epoch [23/100], Train Loss: 1.1734, Train Acc: 48.13%, Test Loss: 1.1467, Test Acc: 49.77%, Time: 35.93
# Epoch [24/100], Train Loss: 1.1710, Train Acc: 48.11%, Test Loss: 1.1435, Test Acc: 50.04%, Time: 36.10
# Epoch [25/100], Train Loss: 1.1729, Train Acc: 48.27%, Test Loss: 1.1443, Test Acc: 49.92%, Time: 37.53
# Epoch [26/100], Train Loss: 1.1678, Train Acc: 48.17%, Test Loss: 1.1413, Test Acc: 49.70%, Time: 36.74
# Epoch [27/100], Train Loss: 1.1675, Train Acc: 48.51%, Test Loss: 1.1391, Test Acc: 50.32%, Time: 36.06
# Epoch [28/100], Train Loss: 1.1636, Train Acc: 48.52%, Test Loss: 1.1367, Test Acc: 49.99%, Time: 36.11
# Epoch [29/100], Train Loss: 1.1588, Train Acc: 48.66%, Test Loss: 1.1347, Test Acc: 51.23%, Time: 35.90
# Epoch [30/100], Train Loss: 1.1604, Train Acc: 48.73%, Test Loss: 1.1326, Test Acc: 50.21%, Time: 36.34
# Epoch [31/100], Train Loss: 1.1580, Train Acc: 48.46%, Test Loss: 1.1352, Test Acc: 50.54%, Time: 36.33
# Epoch [32/100], Train Loss: 1.1569, Train Acc: 48.85%, Test Loss: 1.1318, Test Acc: 50.61%, Time: 35.98
# Epoch [33/100], Train Loss: 1.1545, Train Acc: 49.44%, Test Loss: 1.1292, Test Acc: 50.95%, Time: 36.23
# Epoch [34/100], Train Loss: 1.1526, Train Acc: 49.27%, Test Loss: 1.1311, Test Acc: 50.66%, Time: 35.59
# Epoch [35/100], Train Loss: 1.1496, Train Acc: 49.06%, Test Loss: 1.1191, Test Acc: 50.93%, Time: 36.36
# Epoch [36/100], Train Loss: 1.1477, Train Acc: 49.34%, Test Loss: 1.1293, Test Acc: 50.20%, Time: 36.43
# Epoch [37/100], Train Loss: 1.1455, Train Acc: 49.35%, Test Loss: 1.1275, Test Acc: 50.78%, Time: 36.25
# Epoch [38/100], Train Loss: 1.1452, Train Acc: 49.24%, Test Loss: 1.1207, Test Acc: 50.51%, Time: 36.63
# Epoch [39/100], Train Loss: 1.1425, Train Acc: 49.21%, Test Loss: 1.1202, Test Acc: 50.90%, Time: 36.20
# Epoch [40/100], Train Loss: 1.1415, Train Acc: 49.57%, Test Loss: 1.1194, Test Acc: 50.85%, Time: 35.93
# Epoch [41/100], Train Loss: 1.1415, Train Acc: 49.40%, Test Loss: 1.1176, Test Acc: 51.12%, Time: 36.12
# Epoch [42/100], Train Loss: 1.1367, Train Acc: 49.61%, Test Loss: 1.1154, Test Acc: 51.62%, Time: 36.09
# Epoch [43/100], Train Loss: 1.1372, Train Acc: 50.13%, Test Loss: 1.1154, Test Acc: 51.48%, Time: 36.21
# Epoch [44/100], Train Loss: 1.1301, Train Acc: 50.13%, Test Loss: 1.1181, Test Acc: 51.12%, Time: 36.35
# Epoch [45/100], Train Loss: 1.1312, Train Acc: 49.73%, Test Loss: 1.1118, Test Acc: 51.71%, Time: 36.19
# Epoch [46/100], Train Loss: 1.1329, Train Acc: 50.34%, Test Loss: 1.1095, Test Acc: 51.65%, Time: 36.30
# Epoch [47/100], Train Loss: 1.1273, Train Acc: 50.23%, Test Loss: 1.1105, Test Acc: 51.90%, Time: 36.13
# Epoch [48/100], Train Loss: 1.1291, Train Acc: 49.83%, Test Loss: 1.1101, Test Acc: 51.95%, Time: 35.89
# Epoch [49/100], Train Loss: 1.1256, Train Acc: 50.51%, Test Loss: 1.1075, Test Acc: 51.57%, Time: 36.34
# Epoch [50/100], Train Loss: 1.1255, Train Acc: 50.60%, Test Loss: 1.1123, Test Acc: 51.59%, Time: 36.40
# Epoch [51/100], Train Loss: 1.1258, Train Acc: 50.48%, Test Loss: 1.1051, Test Acc: 52.27%, Time: 36.17
# Epoch [52/100], Train Loss: 1.1224, Train Acc: 50.89%, Test Loss: 1.1015, Test Acc: 52.24%, Time: 36.11
# Epoch [53/100], Train Loss: 1.1194, Train Acc: 50.61%, Test Loss: 1.1070, Test Acc: 51.60%, Time: 36.11
# Epoch [54/100], Train Loss: 1.1208, Train Acc: 50.93%, Test Loss: 1.1081, Test Acc: 51.88%, Time: 36.13
# Epoch [55/100], Train Loss: 1.1194, Train Acc: 50.84%, Test Loss: 1.1141, Test Acc: 51.91%, Time: 37.18
# Epoch [56/100], Train Loss: 1.1177, Train Acc: 50.73%, Test Loss: 1.1031, Test Acc: 51.81%, Time: 35.98
# Epoch [57/100], Train Loss: 1.1185, Train Acc: 50.80%, Test Loss: 1.1075, Test Acc: 52.05%, Time: 37.34
# Epoch [58/100], Train Loss: 1.1129, Train Acc: 50.73%, Test Loss: 1.1034, Test Acc: 51.98%, Time: 36.08
# Epoch [59/100], Train Loss: 1.1004, Train Acc: 51.67%, Test Loss: 1.0917, Test Acc: 52.56%, Time: 36.22
# Epoch [60/100], Train Loss: 1.0940, Train Acc: 52.18%, Test Loss: 1.0895, Test Acc: 52.77%, Time: 35.86
# Epoch [61/100], Train Loss: 1.0940, Train Acc: 51.98%, Test Loss: 1.0898, Test Acc: 52.99%, Time: 35.79
# Epoch [62/100], Train Loss: 1.0963, Train Acc: 51.78%, Test Loss: 1.0888, Test Acc: 52.53%, Time: 36.27
# Epoch [63/100], Train Loss: 1.0925, Train Acc: 51.94%, Test Loss: 1.0884, Test Acc: 52.94%, Time: 36.02
# Epoch [64/100], Train Loss: 1.0973, Train Acc: 51.92%, Test Loss: 1.0887, Test Acc: 52.75%, Time: 36.68
# Epoch [65/100], Train Loss: 1.0950, Train Acc: 52.07%, Test Loss: 1.0893, Test Acc: 52.74%, Time: 36.53
# Epoch [66/100], Train Loss: 1.0965, Train Acc: 51.81%, Test Loss: 1.0892, Test Acc: 52.68%, Time: 36.20
# Epoch [67/100], Train Loss: 1.0972, Train Acc: 51.84%, Test Loss: 1.0881, Test Acc: 52.80%, Time: 36.87
# Epoch [68/100], Train Loss: 1.0906, Train Acc: 52.61%, Test Loss: 1.0894, Test Acc: 52.60%, Time: 36.09
# Epoch [69/100], Train Loss: 1.0939, Train Acc: 52.24%, Test Loss: 1.0890, Test Acc: 52.48%, Time: 36.38
# Epoch [70/100], Train Loss: 1.0895, Train Acc: 52.47%, Test Loss: 1.0869, Test Acc: 52.74%, Time: 36.36
# Epoch [71/100], Train Loss: 1.0937, Train Acc: 52.07%, Test Loss: 1.0883, Test Acc: 52.92%, Time: 36.12
# Epoch [72/100], Train Loss: 1.0879, Train Acc: 52.43%, Test Loss: 1.0873, Test Acc: 52.46%, Time: 36.37
# Epoch [73/100], Train Loss: 1.0933, Train Acc: 52.23%, Test Loss: 1.0870, Test Acc: 52.77%, Time: 36.22
# Epoch [74/100], Train Loss: 1.0894, Train Acc: 52.42%, Test Loss: 1.0887, Test Acc: 52.75%, Time: 36.08
# Epoch [75/100], Train Loss: 1.0899, Train Acc: 52.70%, Test Loss: 1.0869, Test Acc: 52.98%, Time: 36.10
# Epoch [76/100], Train Loss: 1.0896, Train Acc: 52.48%, Test Loss: 1.0880, Test Acc: 52.96%, Time: 36.31
# Epoch [77/100], Train Loss: 1.0847, Train Acc: 52.39%, Test Loss: 1.0868, Test Acc: 52.89%, Time: 35.90
# Epoch [78/100], Train Loss: 1.0881, Train Acc: 52.06%, Test Loss: 1.0871, Test Acc: 52.91%, Time: 36.20
# Epoch [79/100], Train Loss: 1.0889, Train Acc: 52.67%, Test Loss: 1.0858, Test Acc: 52.99%, Time: 36.10
# Epoch [80/100], Train Loss: 1.0822, Train Acc: 52.76%, Test Loss: 1.0862, Test Acc: 53.11%, Time: 36.32
# Epoch [81/100], Train Loss: 1.0876, Train Acc: 52.66%, Test Loss: 1.0861, Test Acc: 53.11%, Time: 36.18
# Epoch [82/100], Train Loss: 1.0842, Train Acc: 51.97%, Test Loss: 1.0865, Test Acc: 53.08%, Time: 36.47
# Epoch [83/100], Train Loss: 1.0841, Train Acc: 52.70%, Test Loss: 1.0862, Test Acc: 52.94%, Time: 36.63
# Epoch [84/100], Train Loss: 1.0845, Train Acc: 52.59%, Test Loss: 1.0859, Test Acc: 53.08%, Time: 36.06
# Epoch [85/100], Train Loss: 1.0861, Train Acc: 52.99%, Test Loss: 1.0856, Test Acc: 52.91%, Time: 36.43
# Epoch [86/100], Train Loss: 1.0887, Train Acc: 52.45%, Test Loss: 1.0856, Test Acc: 53.08%, Time: 36.20
# Epoch [87/100], Train Loss: 1.0882, Train Acc: 52.67%, Test Loss: 1.0856, Test Acc: 53.15%, Time: 36.35
# Epoch [88/100], Train Loss: 1.0889, Train Acc: 52.67%, Test Loss: 1.0859, Test Acc: 53.11%, Time: 36.42
# Epoch [89/100], Train Loss: 1.0889, Train Acc: 52.76%, Test Loss: 1.0854, Test Acc: 53.04%, Time: 36.05
# Epoch [90/100], Train Loss: 1.0864, Train Acc: 52.75%, Test Loss: 1.0861, Test Acc: 53.01%, Time: 36.11
# Epoch [91/100], Train Loss: 1.0882, Train Acc: 52.28%, Test Loss: 1.0857, Test Acc: 52.92%, Time: 36.05
# Epoch [92/100], Train Loss: 1.0849, Train Acc: 53.06%, Test Loss: 1.0855, Test Acc: 52.92%, Time: 36.10
# Epoch [93/100], Train Loss: 1.0828, Train Acc: 52.79%, Test Loss: 1.0853, Test Acc: 52.80%, Time: 36.10
# Epoch [94/100], Train Loss: 1.0879, Train Acc: 52.31%, Test Loss: 1.0855, Test Acc: 53.01%, Time: 35.82
# Epoch [95/100], Train Loss: 1.0851, Train Acc: 52.93%, Test Loss: 1.0856, Test Acc: 52.87%, Time: 36.61
# Epoch [96/100], Train Loss: 1.0873, Train Acc: 52.77%, Test Loss: 1.0862, Test Acc: 52.82%, Time: 36.34
# Epoch [97/100], Train Loss: 1.0847, Train Acc: 52.49%, Test Loss: 1.0855, Test Acc: 52.96%, Time: 37.04
# Epoch [98/100], Train Loss: 1.0859, Train Acc: 52.57%, Test Loss: 1.0860, Test Acc: 52.84%, Time: 36.08
# Epoch [99/100], Train Loss: 1.0837, Train Acc: 52.94%, Test Loss: 1.0850, Test Acc: 52.86%, Time: 36.48
# Epoch [100/100], Train Loss: 1.0831, Train Acc: 52.79%, Test Loss: 1.0854, Test Acc: 53.01%, Time: 36.39
# Finished training the CNN.

# %%
# %% Cell 4: Evaluate the simple custom CNN on the test set and extract embeddings
#
# We compute the accuracy on the test set and also store the embeddings for a subset
# of test samples (first 500) for later comparison.
simple_model.eval()  # set model to evaluation mode
correct = 0
total = 0

# To store embeddings and labels for the first 500 test samples
all_embeddings_simple = []
all_labels_simple = []
all_true = []
all_preds = []

with torch.no_grad():
    for i, (inputs, labels) in enumerate(testloader_simple):
        inputs, labels = inputs.to(device), labels.to(device)
        outputs, embeddings = simple_model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        all_preds.extend(predicted.cpu().numpy())
        all_true.extend(labels.cpu().numpy())
        # Save embeddings and labels until we have 500 samples
        if len(all_embeddings_simple) < 500:
            all_embeddings_simple.append(embeddings.cpu())
            all_labels_simple.append(labels.cpu())
            
accuracy_simple = 100 * correct / total
print(f"Simple CNN Test Accuracy: {accuracy_simple:.2f}%")

# Concatenate embeddings and labels (only take the first 500 samples)
embeddings_custom = torch.cat(all_embeddings_simple, dim=0)[:500]
labels_custom = torch.cat(all_labels_simple, dim=0)[:500]
# Out:
# Simple CNN Test Accuracy: 53.01%

# %%
data = pd.DataFrame({
    'Epoch': range(1, len(test_loss_list) + 1),
    'Train Loss': train_loss_list,
    'Test Loss': test_loss_list
})

# Melt the DataFrame to long format for seaborn
data_long = data.melt('Epoch', var_name='Loss Type', value_name='Loss')

# Plot using seaborn
sns.lineplot(x='Epoch', y='Loss', hue='Loss Type',  palette=['b', 'r'], data=data_long)

# Add labels and title
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train and Tess Loss')

# Show the plot
plt.legend(title='Loss Type')
plt.show()

# %%
data = pd.DataFrame({
    'Epoch': range(1, len(test_loss_list) + 1),
    'Train Accuracy': train_acc_list,
    'Test Accuracy': test_acc_list
})

# Melt the DataFrame to long format for seaborn
data_long = data.melt('Epoch', var_name='Accuracy Type', value_name='Accuracy')

# Plot using seaborn
sns.lineplot(x='Epoch', y='Accuracy', hue='Accuracy Type',  palette=['b', 'r'], data=data_long)

# Add labels and title
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Train and Tess Accuracy')

# Show the plot
plt.legend(title='Accuracy Type')
plt.show()

# %%
class_counts = {class_name: 0 for class_name in dataset.classes}

for idx in trainset_simple.indices:  # Access indices from trainset_simple
    label = dataset.targets[idx]  # Get label using the index
    class_counts[dataset.classes[label]] += 1

total_train_samples = sum(class_counts.values())

# Convert class_counts dictionary to DataFrame (keep count values)
df = pd.DataFrame(list(class_counts.items()), columns=['Class', 'Count'])

# Plot training distribution with count on y-axis
plt.figure(figsize=(8, 5))
ax = sns.barplot(x='Class', y='Count', data=df, palette='cool')

# Annotate bars with percentage values
for p in ax.patches:
    percentage = (p.get_height() / total_train_samples) * 100  # Convert count to percentage
    ax.annotate(f'{percentage:.1f}%', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

# Customize plot
plt.suptitle("Distribution of Train Data", fontsize=20, fontweight='bold')
plt.xticks(rotation=45)
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()
# Out:
# /tmp/ipykernel_262394/3802847234.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Class', y='Count', data=df, palette='cool')

# %%
predicted_counts = {class_name: 0 for class_name in dataset.classes}

for pred in all_preds:
    predicted_counts[dataset.classes[pred]] += 1

total_preds = sum(predicted_counts.values())

# Convert predicted_counts dictionary to DataFrame (keep count values)
df_preds = pd.DataFrame(list(predicted_counts.items()), columns=['Class', 'Count'])

# Plot predicted class distribution with count on y-axis
plt.figure(figsize=(8, 5))
ax = sns.barplot(x='Class', y='Count', data=df_preds, palette="cool")

# Annotate bars with percentage values
for p in ax.patches:
    percentage = (p.get_height() / total_preds) * 100  # Convert count to percentage
    ax.annotate(f'{percentage:.1f}%', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

# Customize plot
plt.suptitle("Distribution of Predicted Test Data", fontsize=20, fontweight='bold')
plt.xticks(rotation=45)
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()
# Out:
# /tmp/ipykernel_262394/1978599949.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Class', y='Count', data=df_preds, palette="cool")

# %%
def class_pred_hist(label):
    true_labels = [testset_simple[i][1] for i in range(len(testset_simple))]

    class_indices = [i for i, true_label in enumerate(true_labels) if true_label == label]

    # Step 2: Track predictions for Class 1 data points
    class_predictions = [all_preds[i] for i in class_indices]

    # Step 3: Count how many times each class was predicted for Class 1 data points
    predicted_counts_class = {class_name: 0 for class_name in dataset.classes}
    for pred in class_predictions:
        predicted_counts_class[dataset.classes[pred]] += 1

    # Convert the dictionary to a DataFrame
    df_class_preds = pd.DataFrame(list(predicted_counts_class.items()), columns=['Class', 'Count'])

    # Step 4: Plot the results
    plt.figure(figsize=(8, 5))
    ax = sns.barplot(x='Class', y='Count', data=df_class_preds, palette="cool")

    # Annotate bars with count values
    for p in ax.patches:
        ax.annotate(f'{int(p.get_height())}', 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

    # Customize plot
    plt.suptitle("Predictions for Data Points in Class "+str(label+2), fontsize=20, fontweight='bold')
    plt.title("Art_CNN_1.0", fontsize=15)
    plt.xticks(rotation=45)
    plt.xlabel("Predicted Class")
    plt.ylabel("Count")
    plt.show()

# %%
class_pred_hist(0)
# Out:
# /tmp/ipykernel_262394/275911575.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Class', y='Count', data=df_class_preds, palette="cool")

# %%
class_pred_hist(1)
# Out:
# /tmp/ipykernel_262394/275911575.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Class', y='Count', data=df_class_preds, palette="cool")

# %%
class_pred_hist(2)
# Out:
# /tmp/ipykernel_262394/275911575.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Class', y='Count', data=df_class_preds, palette="cool")

# %%
class_pred_hist(3)
# Out:
# /tmp/ipykernel_262394/275911575.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Class', y='Count', data=df_class_preds, palette="cool")

# %%
cm = confusion_matrix(all_true, all_preds)

# Adjust class labels to start from 1 instead of 0
class_labels = [str(i+1) for i in range(len(cm))]  # Assuming class indices are 0-based

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.show()

# %%
def log_embeddings(writer, embeddings_dict, metadata_dict, global_step=0):
    """
    Logs embeddings to TensorBoard.

    Parameters:
      writer (SummaryWriter): TensorBoard writer.
      embeddings_dict (dict): A dictionary where keys are model names (str)
                              and values are embeddings (torch.Tensor of shape [N, D]).
      metadata_dict (dict): A dictionary where keys are model names (str)
                            and values are lists of metadata strings for each sample.
      global_step (int): Global training step (for TensorBoard).
    """
    for name, emb in embeddings_dict.items():
        # .add_embedding expects a 2D tensor and an optional metadata list
        writer.add_embedding(emb, metadata=metadata_dict.get(name, None),
                             tag=name, global_step=global_step)
    print("Embeddings logged to TensorBoard.")

# %%
# %% Cell 12: Prepare embeddings from custom, pre‑trained (frozen), and fine‑tuned models and log them
#
# For speed we use only the first 500 test samples from each model.
# Note: Since the models use different input transformations,
# the embeddings come from different networks.
#
# We prepare metadata (the true label for each sample) as a list of strings.
# Then, we log these embeddings using TensorBoard.
num_samples = 500

# For the custom model (simple CNN), we already have embeddings and labels (from Cell 4)
embeddings_custom_np = embeddings_custom.cpu()  # shape: [num_samples, embedding_dim]
metadata_custom = [str(label.item()) for label in labels_custom]

# Create a dictionary of embeddings and metadata
embeddings_dict = {
    "custom": embeddings_custom_np,
}
metadata_dict = {
    "custom": metadata_custom,
}

# Create a TensorBoard SummaryWriter (logs will be saved in the 'runs/embeddings' directory)
log_dir = r"runs/embeddings_3"
if not os.path.exists(log_dir):
    os.makedirs(log_dir)
writer = SummaryWriter(log_dir)

# Log the embeddings (global_step can be set to any value; here we use 0)
log_embeddings(writer, embeddings_dict, metadata_dict, global_step=0)
writer.close()

print("\nTo visualize the embeddings, run in a terminal:\n\n tensorboard --logdir=runs/embeddings\n")
# Out:
# Embeddings logged to TensorBoard.
#
# To visualize the embeddings, run in a terminal:
#
#  tensorboard --logdir=runs/embeddings
